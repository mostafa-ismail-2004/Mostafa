# %% [markdown]
# # Hello World Program
#
# This is a simple Python program that prints 'Hello, World!'

# %%
pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.7 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/12.7 MB 2.8 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.8/12.7 MB 3.2 MB/s eta 0:00:04
#    -------- ------------------------------- 2.6/12.7 MB 3.5 MB/s eta 0:00:03
#    --------- ------------------------------ 2.9/12.7 MB 3.5 MB/s eta 0:00:03
#    --------- ------------------------------ 2.9/12.7 MB 3.5 MB/s eta 0:00:03
#    --------- ------------------------------ 2.9/12.7 MB 3.5 MB/s eta 0:00:03
#    --------- ------------------------------ 3.1/12.7 MB 2.1 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.7/12.7 MB 2.1 MB/s eta 0:00:05
#    ------------- -------------------------- 4.2/12.7 MB 2.0 MB/s eta 0:00:05
# ...

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.0 MB 1.9 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.3/11.0 MB 2.9 MB/s eta 0:00:04
#    ------- -------------------------------- 2.1/11.0 MB 3.3 MB/s eta 0:00:03
#    ------- -------------------------------- 2.1/11.0 MB 3.3 MB/s eta 0:00:03
#    ------- -------------------------------- 2.1/11.0 MB 3.3 MB/s eta 0:00:03
#    -------- ------------------------------- 2.4/11.0 MB 2.0 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.1/11.0 MB 2.2 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.1/11.0 MB 2.2 MB/s eta 0:00:04
#    ---------------- ----------------------- 4.5/11.0 MB 2.4 MB/s eta 0:00:03
# ...

# %%
import pandas as pd
class DataFrame:
    def __init__(self, data):
        self.data = data
df = DataFrame(data = {'Name': ['John', 'Jane', 'Jim', 'Jill'], 'Age': [25, 30, 35, 40]})
df = pd.DataFrame(data = {'Name': ['John', 'Jane', 'Jim', 'Jill'], 'Age': [25, 30, 35, 40]})
df.head()
# Out:
#    Name  Age
# 0  John   25
# 1  Jane   30
# 2   Jim   35
# 3  Jill   40
